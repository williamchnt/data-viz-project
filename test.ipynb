# %%
import pandas as pd

# %%
df = pd.read_csv("../full_2020.csv",low_memory=False)
del df['id_mutation']
del df['numero_disposition']
del df['ancien_code_commune']
del df['ancien_nom_commune']
del df['numero_volume']
del df['ancien_id_parcelle']
del df['lot1_numero']
del df['lot1_surface_carrez']
del df['lot2_numero']
del df['lot2_surface_carrez']
del df['lot3_numero']
del df['lot3_surface_carrez']
del df['lot4_numero']
del df['lot4_surface_carrez']
del df['lot5_numero']
del df['lot5_surface_carrez']
del df['nombre_lots']
del df['code_type_local']
del df['code_nature_culture_speciale']
del df['id_parcelle']
del df['code_nature_culture']
del df['nature_culture']
del df['nature_culture_speciale']
df
# Out:
#         date_mutation nature_mutation  valeur_fonciere  adresse_numero  \
# 0          2020-01-07           Vente           8000.0             NaN
# 1          2020-01-02           Vente           2175.0             NaN
# 2          2020-01-02           Vente           2175.0             NaN
# 3          2020-01-02           Vente           2175.0             NaN
# 4          2020-01-02           Vente           2175.0             NaN
# ...               ...             ...              ...             ...
# 2459555    2020-12-16           Vente        1937500.0            24.0
# 2459556    2020-12-16           Vente        1937500.0            24.0
# 2459557    2020-12-16           Vente        1937500.0            24.0
# 2459558    2020-12-16           Vente        1937500.0            24.0
# 2459559    2020-10-08    Adjudication         255000.0            39.0
#
#         adresse_suffixe        adresse_nom_voie adresse_code_voie  \
# 0                   NaN                FORTUNAT              B063
# 1                   NaN  TERRES DES CINQ SAULES              B124
# 2                   NaN      BOIS DU CHAMP RION              B006
# 3                   NaN             EN COROBERT              B025
# 4                   NaN  TERRES DES CINQ SAULES              B124
# ...                 ...                     ...               ...
# 2459555             NaN         RUE CHANOINESSE              1748
# 2459556             NaN         RUE CHANOINESSE              1748
# 2459557             NaN         RUE CHANOINESSE              1748
# 2459558             NaN         RUE CHANOINESSE              1748
# 2459559             NaN       RUE SAINT-SAUVEUR              8752
#
#          code_postal code_commune              nom_commune code_departement  \
# 0             1250.0        01072                Ceyzériat               01
# 1             1290.0        01203                     Laiz               01
# 2             1290.0        01203                     Laiz               01
# 3             1290.0        01203                     Laiz               01
# 4             1290.0        01203                     Laiz               01
# ...              ...          ...                      ...              ...
# 2459555      75004.0        75104  Paris 4e Arrondissement               75
# 2459556      75004.0        75104  Paris 4e Arrondissement               75
# 2459557      75004.0        75104  Paris 4e Arrondissement               75
# 2459558      75004.0        75104  Paris 4e Arrondissement               75
# 2459559      75002.0        75102  Paris 2e Arrondissement               75
#
#           type_local  surface_reelle_bati  nombre_pieces_principales  \
# 0                NaN                  NaN                        NaN
# 1                NaN                  NaN                        NaN
# 2                NaN                  NaN                        NaN
# 3                NaN                  NaN                        NaN
# 4                NaN                  NaN                        NaN
# ...              ...                  ...                        ...
# 2459555  Appartement                 87.0                        4.0
# 2459556   Dépendance                  NaN                        0.0
# 2459557  Appartement                 82.0                        2.0
# 2459558   Dépendance                  NaN                        0.0
# 2459559  Appartement                 21.0                        1.0
#
#          surface_terrain  longitude   latitude
# 0                 1061.0   5.323540  46.171919
# 1                   85.0   4.893436  46.251868
# 2                 1115.0   4.899919  46.235327
# 3                 1940.0   4.882347  46.246519
# 4                 1148.0   4.894688  46.251820
# ...                  ...        ...        ...
# 2459555            447.0   2.350481  48.854293
# 2459556            447.0   2.350481  48.854293
# 2459557            447.0   2.350481  48.854293
# 2459558            447.0   2.350481  48.854293
# 2459559              NaN   2.348149  48.865935
#
# [2459560 rows x 17 columns]

# %%
df1 = pd.read_csv("../full_2020.csv",low_memory=False,usecols=['date_mutation','nature_mutation','valeur_fonciere','adresse_numero','adresse_suffixe','adresse_nom_voie','adresse_code_voie','code_postal','code_commune','nom_commune','code_departement','type_local','surface_reelle_bati','nombre_pieces_principales','surface_terrain','longitude','latitude'])[['date_mutation','nature_mutation','valeur_fonciere','adresse_numero','adresse_suffixe','adresse_nom_voie','adresse_code_voie','code_postal','code_commune','nom_commune','code_departement','type_local','surface_reelle_bati','nombre_pieces_principales','surface_terrain','longitude','latitude']]
df1
# Out:
#         date_mutation nature_mutation  valeur_fonciere  adresse_numero  \
# 0          2020-01-07           Vente           8000.0             NaN
# 1          2020-01-02           Vente           2175.0             NaN
# 2          2020-01-02           Vente           2175.0             NaN
# 3          2020-01-02           Vente           2175.0             NaN
# 4          2020-01-02           Vente           2175.0             NaN
# ...               ...             ...              ...             ...
# 2459555    2020-12-16           Vente        1937500.0            24.0
# 2459556    2020-12-16           Vente        1937500.0            24.0
# 2459557    2020-12-16           Vente        1937500.0            24.0
# 2459558    2020-12-16           Vente        1937500.0            24.0
# 2459559    2020-10-08    Adjudication         255000.0            39.0
#
#         adresse_suffixe        adresse_nom_voie adresse_code_voie  \
# 0                   NaN                FORTUNAT              B063
# 1                   NaN  TERRES DES CINQ SAULES              B124
# 2                   NaN      BOIS DU CHAMP RION              B006
# 3                   NaN             EN COROBERT              B025
# 4                   NaN  TERRES DES CINQ SAULES              B124
# ...                 ...                     ...               ...
# 2459555             NaN         RUE CHANOINESSE              1748
# 2459556             NaN         RUE CHANOINESSE              1748
# 2459557             NaN         RUE CHANOINESSE              1748
# 2459558             NaN         RUE CHANOINESSE              1748
# 2459559             NaN       RUE SAINT-SAUVEUR              8752
#
#          code_postal code_commune              nom_commune code_departement  \
# 0             1250.0        01072                Ceyzériat               01
# 1             1290.0        01203                     Laiz               01
# 2             1290.0        01203                     Laiz               01
# 3             1290.0        01203                     Laiz               01
# 4             1290.0        01203                     Laiz               01
# ...              ...          ...                      ...              ...
# 2459555      75004.0        75104  Paris 4e Arrondissement               75
# 2459556      75004.0        75104  Paris 4e Arrondissement               75
# 2459557      75004.0        75104  Paris 4e Arrondissement               75
# 2459558      75004.0        75104  Paris 4e Arrondissement               75
# 2459559      75002.0        75102  Paris 2e Arrondissement               75
#
#           type_local  surface_reelle_bati  nombre_pieces_principales  \
# 0                NaN                  NaN                        NaN
# 1                NaN                  NaN                        NaN
# 2                NaN                  NaN                        NaN
# 3                NaN                  NaN                        NaN
# 4                NaN                  NaN                        NaN
# ...              ...                  ...                        ...
# 2459555  Appartement                 87.0                        4.0
# 2459556   Dépendance                  NaN                        0.0
# 2459557  Appartement                 82.0                        2.0
# 2459558   Dépendance                  NaN                        0.0
# 2459559  Appartement                 21.0                        1.0
#
#          surface_terrain  longitude   latitude
# 0                 1061.0   5.323540  46.171919
# 1                   85.0   4.893436  46.251868
# 2                 1115.0   4.899919  46.235327
# 3                 1940.0   4.882347  46.246519
# 4                 1148.0   4.894688  46.251820
# ...                  ...        ...        ...
# 2459555            447.0   2.350481  48.854293
# 2459556            447.0   2.350481  48.854293
# 2459557            447.0   2.350481  48.854293
# 2459558            447.0   2.350481  48.854293
# 2459559              NaN   2.348149  48.865935
#
# [2459560 rows x 17 columns]

# %%
df2=pd.read_csv("../full_2020.csv",low_memory=False)
